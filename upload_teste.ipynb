# %%
# !find
# Out:
# .
# ./jogar_quiz.php
# ./assets
# ./brand.php
# ./.htaccess
# ./.gitignore
# ./termo.php
# ./abrir_ws.php
# ./mentor_voz.php
# ./chat_ia.php
# ./repositorio.php
# ./req_command.py
# ./cadastro.php
# ./testePython.py
# ./404.html
# ./js
# ./.user.ini
# ./cmdoptions.py
# ./parser.py
# ./502.html
# ./gestao_usuarios.php
# ./.env
# ./composer.lock
# ./criar_workspace.py
# ./__pycache__
# ./__pycache__/progress_bars.cpython-311.pyc
# ./__pycache__/parser.cpython-311.pyc
# ./__pycache__/__init__.cpython-311.pyc
# ./__pycache__/spinners.cpython-311.pyc
# ./__pycache__/command_context.cpython-311.pyc
# ./__pycache__/base_command.cpython-311.pyc
# ./__pycache__/main.cpython-311.pyc
# ./__pycache__/status_codes.cpython-311.pyc
# ./__pycache__/req_command.cpython-311.pyc
# ./__pycache__/autocompletion.cpython-311.pyc
# ./__pycache__/main_parser.cpython-311.pyc
# ./__pycache__/cmdoptions.cpython-311.pyc
# ./teste_banco_real.py
# ./nova_senha.php
# ./command_context.py
# ./quizzes.php
# ...
